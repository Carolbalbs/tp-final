# %% [markdown]
# # Análise Estrutura Obrigatória

# %% [markdown]
# ## Tratamento da rede

# %%
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import numpy as np
import collections
import time
import warnings
import os

# %%
warnings.filterwarnings("ignore")

# %%
EDGE_FILE = "com-lj.all.cmty.txt"

print("=" * 60)
print("ANÁLISE ESTRUTURAL - LiveJournal")
print("=" * 60)

print("\n[1/9] Carregando grafo...")
t0 = time.time()

# %%
G = nx.read_edgelist(
    EDGE_FILE, 
    comments="#",
    nodetype=int,
    create_using=nx.Graph()
)
print(f"  Tempo de carregamento: {time.time() - t0:.1f}s")
